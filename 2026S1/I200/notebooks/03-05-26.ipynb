# %% [markdown]
# ## Clase 1 – Introducción al lenguaje C

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th style="text-align:left">Python</th>
#       <th style="text-align:left">C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="text-align:left">Python es un lenguaje interpretado, lo que significa que el
# código que escribimos es procesado por un intérprete que, en tiempo de ejecución, traduce cada
# instrucción a código máquina y la ejecuta. </td>
#       <td style="text-align:left">C, en cambio, es un lenguaje compilado. Esto implica que existe un compilador que, en tiempo de
# compilación, traduce todo el código fuente a código máquina y genera un archivo ejecutable.
# Dicho ejecutable puede luego ejecutarse directamente en la computadora.</td>
#     </tr>
#   </tbody>
# </table>

# %%
investigar site_t

# %%
for i in range(5):
print(i)

# %%
#include <stdio.h>

int main() {
    for (int i = 0; i < 5; i++)
    {
        printf("%d\n", i);
    }
    return 0;
}

 # funcion principal se defiene como int porq devuelve un integer (0/1 - se ejecuto bien o no)
